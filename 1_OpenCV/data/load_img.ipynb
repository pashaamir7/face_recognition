# %%
import numpy as np
import cv2
import matplotlib.image as matimg
import matplotlib.pyplot as plt
from PIL import Image

# %%
# OpenCV-BGR- numpy array
img_cv = cv2.imread(r"C:\Users\dell\Desktop\Minor_project_facerec\face\1_OpenCV\data\flying_bird.jpg")
# matplotlib-rgb
img_mat=matimg.imread(r"C:\Users\dell\Desktop\Minor_project_facerec\face\1_OpenCV\data\flying_bird.jpg")
# #pil-rgb-object
img_pil = Image.open(r"C:\Users\dell\Desktop\Minor_project_facerec\face\1_OpenCV\data\flying_bird.jpg")

# %%
print(img_mat)
# Out:
# [[[ 92  48  21]
#   [ 90  46  19]
#   [ 88  42  16]
#   ...
#   [ 13  14   0]
#   [ 10  11   0]
#   [ 14  15   0]]
#
#  [[ 88  44  17]
#   [ 87  43  16]
#   [ 87  41  15]
#   ...
#   [ 19  20   4]
#   [ 16  17   1]
#   [ 12  13   0]]
#
#  [[ 91  45  19]
#   [ 91  45  19]
#   [ 92  45  19]
#   ...
#   [ 21  22   4]
#   [ 22  23   7]
#   [ 14  15   0]]
#
#  ...
#
#  [[ 88  57  29]
#   [ 95  64  36]
#   [ 97  65  40]
#   ...
#   [ 77 102   1]
#   [ 74  98   2]
#   [ 73  97   1]]
#
#  [[ 92  62  36]
#   [ 94  64  38]
#   [ 95  65  39]
#   ...
#   [ 77 102   1]
#   [ 75  99   3]
#   [ 73  97   1]]
#
#  [[ 92  62  36]
#   [ 90  60  34]
#   [ 90  60  34]
#   ...
#   [ 75 100   0]
#   [ 73  97   1]
#   [ 73  97   1]]]

# %%
print(img_cv)
# Out:
# [[[ 21  48  92]
#   [ 19  46  90]
#   [ 16  42  88]
#   ...
#   [  0  14  13]
#   [  0  11  10]
#   [  0  15  14]]
#
#  [[ 17  44  88]
#   [ 16  43  87]
#   [ 15  41  87]
#   ...
#   [  4  20  19]
#   [  1  17  16]
#   [  0  13  12]]
#
#  [[ 19  45  91]
#   [ 19  45  91]
#   [ 19  45  92]
#   ...
#   [  4  22  21]
#   [  7  23  22]
#   [  0  15  14]]
#
#  ...
#
#  [[ 29  57  88]
#   [ 36  64  95]
#   [ 40  65  97]
#   ...
#   [  1 102  77]
#   [  2  98  74]
#   [  1  97  73]]
#
#  [[ 36  62  92]
#   [ 38  64  94]
#   [ 39  65  95]
#   ...
#   [  1 102  77]
#   [  3  99  75]
#   [  1  97  73]]
#
#  [[ 36  62  92]
#   [ 34  60  90]
#   [ 34  60  90]
#   ...
#   [  0 100  75]
#   [  1  97  73]
#   [  1  97  73]]]

# %%
img_pil_arr=np.array(img_pil)
print(img_pil_arr)
img_pil
# Out:
# [[[ 92  48  21]
#   [ 90  46  19]
#   [ 88  42  16]
#   ...
#   [ 13  14   0]
#   [ 10  11   0]
#   [ 14  15   0]]
#
#  [[ 88  44  17]
#   [ 87  43  16]
#   [ 87  41  15]
#   ...
#   [ 19  20   4]
#   [ 16  17   1]
#   [ 12  13   0]]
#
#  [[ 91  45  19]
#   [ 91  45  19]
#   [ 92  45  19]
#   ...
#   [ 21  22   4]
#   [ 22  23   7]
#   [ 14  15   0]]
#
#  ...
#
#  [[ 88  57  29]
#   [ 95  64  36]
#   [ 97  65  40]
#   ...
#   [ 77 102   1]
#   [ 74  98   2]
#   [ 73  97   1]]
#
#  [[ 92  62  36]
#   [ 94  64  38]
#   [ 95  65  39]
#   ...
#   [ 77 102   1]
#   [ 75  99   3]
#   [ 73  97   1]]
#
#  [[ 92  62  36]
#   [ 90  60  34]
#   [ 90  60  34]
#   ...
#   [ 75 100   0]
#   [ 73  97   1]
#   [ 73  97   1]]]
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,3,1)
plt.imshow(img_cv)
plt.axis('off')
plt.title('open cv')

plt.subplot(1,3,2)
plt.imshow(img_mat)
plt.axis('off')
plt.title('plotlib')

plt.subplot(1,3,3)
plt.imshow(img_pil_arr)
plt.axis('off')
plt.title('pilimg')
# Out:
# Text(0.5, 1.0, 'pilimg')

# %%
img_cv.shapet
# Out:
# (480, 640, 3)

# %%
#numpy slicing
b=img_cv[:,:,0]
g=img_cv[:,:,1]
r=img_cv[:,:,2]

# %%
cv2.imshow('blue channel',b)
cv2.imshow('green channel',g)
cv2.imshow('red channel',r)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
