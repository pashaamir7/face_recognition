# %%
import numpy as np
import cv2
from glob import glob
import matplotlib.pyplot as plt

# %%
fpath=glob(r'C:\Users\dell\Desktop\Minor_project_facerec\face\2_Train_FaceRecognition_with_ML\data\female\*.jpg')
mpath=glob(r'C:\Users\dell\Desktop\Minor_project_facerec\face\2_Train_FaceRecognition_with_ML\data\male\*.jpg')

# %%
print("The number of images in female path =",len(fpath))
print("The number of images in male path =",len(mpath))
# Out:
# The number of images in female path = 4762
# The number of images in male path = 5399

# %%
#step1 Read image and convert to RGB
img=cv2.imread(fpath[0])
img_rgb=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#Step 2 Apply haar cascadeclassifier
haar=cv2.CascadeClassifier(r'C:\Users\dell\Desktop\Minor_project_facerec\face\2_Train_FaceRecognition_with_ML\model\haarcascade_frontalface_default.xml')

gray = cv2.cvtColor(img_rgb,cv2.COLOR_BGR2GRAY)
faces_list=haar.detectMultiScale(gray,1.5,5)

for x,y,w,h in faces_list:
    cv2.rectangle(img_rgb, (x,y),(x+w,y+h),(0,255,0),2)
    # step -3:crrop image
    roi=img_rgb[y:y+h,x:x+w]
    plt.imshow(roi)
    plt.axis('off')
    plt.show()

# %%
plt.imshow(img_rgb)
plt.axis('off')
plt.show()

# %%
for i in range(len(fpath)): 
    try: 
        
        #step1 Read image and convert to RGB
        img=cv2.imread(fpath[i])
        img_rgb=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        #Step 2 Apply haar cascadeclassifier

        gray = cv2.cvtColor(img_rgb,cv2.COLOR_BGR2GRAY)
        faces_list=haar.detectMultiScale(gray,1.5,5)

        for x,y,w,h in faces_list:
            cv2.rectangle(img_rgb, (x,y),(x+w,y+h),(0,255,0),2)
            # step -3:crrop image
            roi=img[y:y+h,x:x+w]
            cv2.imwrite(f'C:\\Users\\dell\\Desktop\\Minor_project_facerec\\face\\2_Train_FaceRecognition_with_ML\\crop_data\\female//female_{i}.jpg',roi)
            print('Image successfully processed')
    
    except:
        print('Unable to print the image')
# Out:
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# ...

# %% [markdown]
# ###Crop male images

# %%
for i in range(len(mpath)): 
    try: 
        
        #step1 Read image and convert to RGB
        img=cv2.imread(mpath[i])
        img_rgb=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        #Step 2 Apply haar cascadeclassifier

        gray = cv2.cvtColor(img_rgb,cv2.COLOR_BGR2GRAY)
        faces_list=haar.detectMultiScale(gray,1.5,5)

        for x,y,w,h in faces_list:
            cv2.rectangle(img_rgb, (x,y),(x+w,y+h),(0,255,0),2)
            # step -3:crrop image
            roi=img[y:y+h,x:x+w]
            cv2.imwrite(f'C:\\Users\\dell\\Desktop\\Minor_project_facerec\\face\\2_Train_FaceRecognition_with_ML\\crop_data\\male//male_{i}.jpg',roi)
            print('Image successfully processed')
    
    except:
        print('Unable to print the image')
# Out:
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# Image successfully processed
# ...
